# %%
# %load xml_testing.py
from Bio import Entrez
import pandas as pd
handle = open('pubmed_result_tighe.xml')
records = Entrez.parse(handle)

# %%
x = pd.DataFrame.from_dict(records)

# %%
x
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for record in records:
    print(record['MedlineCitation']['Article']['Abstract'])

    
    
# for record in records:
#     print (record)
# Out:
# {'AbstractText': [StringElement('Dendritic cells (DCs) are key players in the induction and re-elicitation of TH2 responses to allergens. We have previously shown that different C-type lectin receptors on DCs play a major role in allergen recognition and uptake. In particular, mannose receptor (MR), through modulation of Toll-like receptor (TLR) 4 signaling, can regulate indoleamine 2,3-dioxygenase (IDO) activity, favoring TH2 responses. Interestingly, the aryl hydrocarbon receptor (AhR), a ligand-dependent transcription factor with an emerging role in immune modulation, has been implicated in IDO activation in response to TLR stimulation.', attributes={'Label': 'BACKGROUND', 'NlmCategory': 'BACKGROUND'}), StringElement('Here we investigated how allergens and lectins modulate the TLR4-AhR-IDO axis in human monocyte-derived DCs.', attributes={'Label': 'OBJECTIVE', 'NlmCategory': 'OBJECTIVE'}), StringElement('Using a combination of genomics, proteomics, and immunologic studies, we inve
# ...

# %%
import lxml
tree = etree.parse('pubmed_result_tighe.xml')

for element in tree.iter():
    print (element.tag)

print(root.tag)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-32-fd5c1a332614> in <module>()
# ----> 1 import lxml
#       2 tree = etree.parse('pubmed_result_tighe.xml')
#       3
#       4 for element in tree.iter():
#       5     print (element.tag)
#
# ImportError: No module named 'lxml'
